# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# A bit of setup

FOLDERNAME = '682/assignment1'

import sys
# sys.path.append('content/drive/My Drive/{}'.format(FOLDERNAME))
sys.path.insert(0,'/content/drive/My Drive/{}'.format(FOLDERNAME))

from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt

from cs682.classifiers.neural_net import TwoLayerNet


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %cd drive/MyDrive/682/assignment1/

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# /content/drive/MyDrive/682/assignment1

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs682/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs682/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs682.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 4.447646e-11
# W2 max relative error: 3.440708e-09
# b1 max relative error: 2.738421e-09
# W1 max relative error: 3.561318e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.017149607938732048

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs682.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs682/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
def plot_stats(stats):
  plt.subplot(2, 1, 1)
  plt.plot(stats['loss_history'])
  plt.title('Loss history')
  plt.xlabel('Iteration')
  plt.ylabel('Loss')

  plt.subplot(2, 1, 2)
  plt.plot(stats['train_acc_history'], label='train')
  plt.plot(stats['val_acc_history'], label='val')
  plt.title('Classification accuracy history')
  plt.xlabel('Epoch')
  plt.ylabel('Clasification accuracy')
  plt.legend()
  plt.show()

# %%
plot_stats(stats)

# %%
from cs682.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
results = {}
input_size = 32 * 32 * 3
num_classes = 10
best_val = -1
best_stats = None
best_net = None
batch_sizes = [100, 200, 250, 300]
learning_rates = [1e-3, 1e-4, 3e-4, 2e-3, 3e-3]
regularization_strengths = [5e-5, 7e-5, 5e-6, 0.25] 
hidden_sizes = [10, 20, 50, 60]  # 50 is the best so deleting that from loop
best_hidden_size = 50

for lr in learning_rates:
  for reg in regularization_strengths:
    for batch_size in batch_sizes:
      net = TwoLayerNet(input_size, best_hidden_size, num_classes)
      print(f"Doing batch size: {batch_size}, lr: {lr}, reg: {reg}", )
      stats = net.train(X_train, y_train, X_val, y_val,
              num_iters=1000, batch_size=batch_size,
              learning_rate=lr, learning_rate_decay=0.95,
              reg=reg, verbose=True)
      
      y_pred_train = net.predict(X_train)
      y_pred_val = net.predict(X_val)
      train_ac = np.mean(y_pred_train == y_train)
      val_ac = np.mean(y_pred_val == y_val)

      results[(lr, reg, batch_size)] = (train_ac, val_ac)
      print('Training, Validation accuracy: ', train_ac, val_ac)
      # saving the network if it has better accuracy till now
      if (val_ac > best_val):
        best_val = val_ac
        best_net = net
        best_params = [lr, reg, batch_size]
        best_stats = stats

print("lr, reg, batch_size: ", best_params)
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# Doing batch size: 100, lr: 0.001, reg: 5e-05
# iteration 0 / 1000: loss 2.302588
# iteration 100 / 1000: loss 1.885078
# iteration 200 / 1000: loss 1.777908
# iteration 300 / 1000: loss 1.725093
# iteration 400 / 1000: loss 1.655123
# iteration 500 / 1000: loss 1.600473
# iteration 600 / 1000: loss 1.719638
# iteration 700 / 1000: loss 1.568586
# iteration 800 / 1000: loss 1.472968
# iteration 900 / 1000: loss 1.687004
# Training, Validation accuracy:  0.454734693877551 0.458
# Doing batch size: 200, lr: 0.001, reg: 5e-05
# iteration 0 / 1000: loss 2.302645
# iteration 100 / 1000: loss 1.986642
# iteration 200 / 1000: loss 1.817312
# iteration 300 / 1000: loss 1.762945
# iteration 400 / 1000: loss 1.492101
# iteration 500 / 1000: loss 1.543040
# iteration 600 / 1000: loss 1.395207
# iteration 700 / 1000: loss 1.642863
# iteration 800 / 1000: loss 1.581075
# iteration 900 / 1000: loss 1.451842
# Training, Validation accuracy:  0.4916530612244898 0.468
# Doing batch size: 250, lr: 0.001, reg: 5e-05
# iteration 0 / 1000: loss 2.302590
# iteration 100 / 1000: loss 1.930962
# iteration 200 / 1000: loss 1.790893
# iteration 300 / 1000: loss 1.635075
# iteration 400 / 1000: loss 1.598631
# iteration 500 / 1000: loss 1.619297
# iteration 600 / 1000: loss 1.550399
# iteration 700 / 1000: loss 1.554036
# iteration 800 / 1000: loss 1.507113
# iteration 900 / 1000: loss 1.424038
# Training, Validation accuracy:  0.49518367346938774 0.484
# Doing batch size: 300, lr: 0.001, reg: 5e-05
# iteration 0 / 1000: loss 2.302583
# iteration 100 / 1000: loss 1.902030
# iteration 200 / 1000: loss 1.778275
# iteration 300 / 1000: loss 1.602532
# iteration 400 / 1000: loss 1.666680
# iteration 500 / 1000: loss 1.511739
# iteration 600 / 1000: loss 1.506349
# iteration 700 / 1000: loss 1.466412
# iteration 800 / 1000: loss 1.530419
# iteration 900 / 1000: loss 1.459292
# Training, Validation accuracy:  0.507061224489796 0.474
# Doing batch size: 100, lr: 0.001, reg: 7e-05
# iteration 0 / 1000: loss 2.302596
# iteration 100 / 1000: loss 1.915875
# iteration 200 / 1000: loss 1.884323
# iteration 300 / 1000: loss 1.588359
# iteration 400 / 1000: loss 1.921620
# iteration 500 / 1000: loss 1.774807
# iteration 600 / 1000: loss 1.557033
# iteration 700 / 1000: loss 1.729668
# iteration 800 / 1000: loss 1.325994
# iteration 900 / 1000: loss 1.535325
# Training, Validation accuracy:  0.47346938775510206 0.472
# Doing batch size: 200, lr: 0.001, reg: 7e-05
# iteration 0 / 1000: loss 2.302568
# iteration 100 / 1000: loss 1.968579
# iteration 200 / 1000: loss 1.750665
# iteration 300 / 1000: loss 1.647586
# iteration 400 / 1000: loss 1.575808
# iteration 500 / 1000: loss 1.483760
# iteration 600 / 1000: loss 1.444282
# iteration 700 / 1000: loss 1.584937
# iteration 800 / 1000: loss 1.214518
# iteration 900 / 1000: loss 1.449850
# Training, Validation accuracy:  0.49689795918367347 0.48
# Doing batch size: 250, lr: 0.001, reg: 7e-05
# iteration 0 / 1000: loss 2.302566
# iteration 100 / 1000: loss 1.965063
# iteration 200 / 1000: loss 1.705464
# iteration 300 / 1000: loss 1.713403
# iteration 400 / 1000: loss 1.634069
# iteration 500 / 1000: loss 1.607766
# iteration 600 / 1000: loss 1.598602
# iteration 700 / 1000: loss 1.563951
# iteration 800 / 1000: loss 1.610065
# iteration 900 / 1000: loss 1.443958
# Training, Validation accuracy:  0.48914285714285716 0.476
# Doing batch size: 300, lr: 0.001, reg: 7e-05
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 1.897150
# iteration 200 / 1000: loss 1.700938
# iteration 300 / 1000: loss 1.603742
# iteration 400 / 1000: loss 1.579192
# iteration 500 / 1000: loss 1.525297
# iteration 600 / 1000: loss 1.563973
# iteration 700 / 1000: loss 1.468248
# iteration 800 / 1000: loss 1.519065
# iteration 900 / 1000: loss 1.424447
# Training, Validation accuracy:  0.503 0.467
# Doing batch size: 100, lr: 0.001, reg: 5e-06
# iteration 0 / 1000: loss 2.302592
# iteration 100 / 1000: loss 1.824401
# iteration 200 / 1000: loss 1.791494
# iteration 300 / 1000: loss 1.608475
# iteration 400 / 1000: loss 1.563010
# iteration 500 / 1000: loss 1.567508
# iteration 600 / 1000: loss 1.659449
# iteration 700 / 1000: loss 1.407365
# iteration 800 / 1000: loss 1.594350
# iteration 900 / 1000: loss 1.539276
# Training, Validation accuracy:  0.4753673469387755 0.465
# Doing batch size: 200, lr: 0.001, reg: 5e-06
# iteration 0 / 1000: loss 2.302561
# iteration 100 / 1000: loss 1.920079
# iteration 200 / 1000: loss 1.882040
# iteration 300 / 1000: loss 1.766009
# iteration 400 / 1000: loss 1.670592
# iteration 500 / 1000: loss 1.536746
# iteration 600 / 1000: loss 1.569236
# iteration 700 / 1000: loss 1.392940
# iteration 800 / 1000: loss 1.455653
# iteration 900 / 1000: loss 1.590233
# Training, Validation accuracy:  0.48275510204081634 0.471
# Doing batch size: 250, lr: 0.001, reg: 5e-06
# iteration 0 / 1000: loss 2.302579
# iteration 100 / 1000: loss 1.894845
# iteration 200 / 1000: loss 1.787369
# iteration 300 / 1000: loss 1.644075
# iteration 400 / 1000: loss 1.650399
# iteration 500 / 1000: loss 1.584330
# iteration 600 / 1000: loss 1.471595
# iteration 700 / 1000: loss 1.521883
# iteration 800 / 1000: loss 1.407598
# iteration 900 / 1000: loss 1.337416
# Training, Validation accuracy:  0.49648979591836734 0.475
# Doing batch size: 300, lr: 0.001, reg: 5e-06
# iteration 0 / 1000: loss 2.302612
# iteration 100 / 1000: loss 1.970462
# iteration 200 / 1000: loss 1.807262
# iteration 300 / 1000: loss 1.594695
# iteration 400 / 1000: loss 1.605272
# iteration 500 / 1000: loss 1.580992
# iteration 600 / 1000: loss 1.515644
# iteration 700 / 1000: loss 1.355277
# iteration 800 / 1000: loss 1.439522
# iteration 900 / 1000: loss 1.420834
# Training, Validation accuracy:  0.5053265306122449 0.472
# Doing batch size: 100, lr: 0.001, reg: 0.25
# iteration 0 / 1000: loss 2.302939
# iteration 100 / 1000: loss 1.935091
# iteration 200 / 1000: loss 1.590885
# iteration 300 / 1000: loss 1.840487
# iteration 400 / 1000: loss 1.645454
# iteration 500 / 1000: loss 1.742302
# iteration 600 / 1000: loss 1.556837
# iteration 700 / 1000: loss 1.420012
# iteration 800 / 1000: loss 1.531669
# iteration 900 / 1000: loss 1.474957
# Training, Validation accuracy:  0.44679591836734694 0.442
# Doing batch size: 200, lr: 0.001, reg: 0.25
# iteration 0 / 1000: loss 2.302965
# iteration 100 / 1000: loss 2.017198
# iteration 200 / 1000: loss 1.823828
# iteration 300 / 1000: loss 1.765479
# iteration 400 / 1000: loss 1.636517
# iteration 500 / 1000: loss 1.660139
# iteration 600 / 1000: loss 1.490027
# iteration 700 / 1000: loss 1.555035
# iteration 800 / 1000: loss 1.450347
# iteration 900 / 1000: loss 1.580852
# Training, Validation accuracy:  0.4876734693877551 0.468
# Doing batch size: 250, lr: 0.001, reg: 0.25
# iteration 0 / 1000: loss 2.302956
# iteration 100 / 1000: loss 1.904758
# iteration 200 / 1000: loss 1.804362
# iteration 300 / 1000: loss 1.795986
# iteration 400 / 1000: loss 1.609455
# iteration 500 / 1000: loss 1.523332
# iteration 600 / 1000: loss 1.664762
# iteration 700 / 1000: loss 1.575150
# iteration 800 / 1000: loss 1.534322
# iteration 900 / 1000: loss 1.467048
# Training, Validation accuracy:  0.4910408163265306 0.48
# Doing batch size: 300, lr: 0.001, reg: 0.25
# iteration 0 / 1000: loss 2.302957
# iteration 100 / 1000: loss 1.895142
# iteration 200 / 1000: loss 1.765856
# iteration 300 / 1000: loss 1.738944
# iteration 400 / 1000: loss 1.559581
# iteration 500 / 1000: loss 1.651994
# iteration 600 / 1000: loss 1.590561
# iteration 700 / 1000: loss 1.545621
# iteration 800 / 1000: loss 1.519765
# iteration 900 / 1000: loss 1.597005
# Training, Validation accuracy:  0.4929387755102041 0.482
# Doing batch size: 100, lr: 0.0001, reg: 5e-05
# iteration 0 / 1000: loss 2.302594
# iteration 100 / 1000: loss 2.302105
# iteration 200 / 1000: loss 2.298581
# iteration 300 / 1000: loss 2.256862
# iteration 400 / 1000: loss 2.204615
# iteration 500 / 1000: loss 2.013049
# iteration 600 / 1000: loss 1.974915
# iteration 700 / 1000: loss 1.988212
# iteration 800 / 1000: loss 1.882999
# iteration 900 / 1000: loss 1.840574
# Training, Validation accuracy:  0.2912448979591837 0.288
# Doing batch size: 200, lr: 0.0001, reg: 5e-05
# iteration 0 / 1000: loss 2.302600
# iteration 100 / 1000: loss 2.302172
# iteration 200 / 1000: loss 2.297171
# iteration 300 / 1000: loss 2.243671
# iteration 400 / 1000: loss 2.218902
# iteration 500 / 1000: loss 2.156106
# iteration 600 / 1000: loss 2.084602
# iteration 700 / 1000: loss 1.996474
# iteration 800 / 1000: loss 1.956410
# iteration 900 / 1000: loss 1.929068
# Training, Validation accuracy:  0.2856938775510204 0.286
# Doing batch size: 250, lr: 0.0001, reg: 5e-05
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 2.302136
# iteration 200 / 1000: loss 2.296127
# iteration 300 / 1000: loss 2.251848
# iteration 400 / 1000: loss 2.145977
# iteration 500 / 1000: loss 2.154895
# iteration 600 / 1000: loss 2.064899
# iteration 700 / 1000: loss 2.053087
# iteration 800 / 1000: loss 2.063843
# iteration 900 / 1000: loss 1.976210
# Training, Validation accuracy:  0.2836734693877551 0.286
# Doing batch size: 300, lr: 0.0001, reg: 5e-05
# iteration 0 / 1000: loss 2.302582
# iteration 100 / 1000: loss 2.302086
# iteration 200 / 1000: loss 2.296794
# iteration 300 / 1000: loss 2.262145
# iteration 400 / 1000: loss 2.207648
# iteration 500 / 1000: loss 2.101212
# iteration 600 / 1000: loss 2.020908
# iteration 700 / 1000: loss 2.008490
# iteration 800 / 1000: loss 1.985521
# iteration 900 / 1000: loss 1.844741
# Training, Validation accuracy:  0.2944081632653061 0.284
# Doing batch size: 100, lr: 0.0001, reg: 7e-05
# iteration 0 / 1000: loss 2.302577
# iteration 100 / 1000: loss 2.301933
# iteration 200 / 1000: loss 2.295796
# iteration 300 / 1000: loss 2.254882
# iteration 400 / 1000: loss 2.065286
# iteration 500 / 1000: loss 2.045677
# iteration 600 / 1000: loss 2.089040
# iteration 700 / 1000: loss 1.950279
# iteration 800 / 1000: loss 2.005522
# iteration 900 / 1000: loss 1.973421
# Training, Validation accuracy:  0.29973469387755103 0.288
# Doing batch size: 200, lr: 0.0001, reg: 7e-05
# iteration 0 / 1000: loss 2.302582
# iteration 100 / 1000: loss 2.302220
# iteration 200 / 1000: loss 2.297467
# iteration 300 / 1000: loss 2.268163
# iteration 400 / 1000: loss 2.209534
# iteration 500 / 1000: loss 2.139879
# iteration 600 / 1000: loss 2.084182
# iteration 700 / 1000: loss 2.029977
# iteration 800 / 1000: loss 1.952012
# iteration 900 / 1000: loss 1.937646
# Training, Validation accuracy:  0.281734693877551 0.287
# Doing batch size: 250, lr: 0.0001, reg: 7e-05
# iteration 0 / 1000: loss 2.302579
# iteration 100 / 1000: loss 2.302299
# iteration 200 / 1000: loss 2.299432
# iteration 300 / 1000: loss 2.272708
# iteration 400 / 1000: loss 2.194506
# iteration 500 / 1000: loss 2.159609
# iteration 600 / 1000: loss 2.058380
# iteration 700 / 1000: loss 2.049546
# iteration 800 / 1000: loss 1.987803
# iteration 900 / 1000: loss 2.021228
# Training, Validation accuracy:  0.28814285714285715 0.287
# Doing batch size: 300, lr: 0.0001, reg: 7e-05
# iteration 0 / 1000: loss 2.302591
# iteration 100 / 1000: loss 2.302161
# iteration 200 / 1000: loss 2.298325
# iteration 300 / 1000: loss 2.258356
# iteration 400 / 1000: loss 2.215434
# iteration 500 / 1000: loss 2.050532
# iteration 600 / 1000: loss 2.059204
# iteration 700 / 1000: loss 2.051231
# iteration 800 / 1000: loss 1.993707
# iteration 900 / 1000: loss 1.933614
# Training, Validation accuracy:  0.2852857142857143 0.284
# Doing batch size: 100, lr: 0.0001, reg: 5e-06
# iteration 0 / 1000: loss 2.302565
# iteration 100 / 1000: loss 2.301848
# iteration 200 / 1000: loss 2.294572
# iteration 300 / 1000: loss 2.262378
# iteration 400 / 1000: loss 2.194146
# iteration 500 / 1000: loss 2.077893
# iteration 600 / 1000: loss 2.103983
# iteration 700 / 1000: loss 1.953415
# iteration 800 / 1000: loss 1.939811
# iteration 900 / 1000: loss 2.004703
# Training, Validation accuracy:  0.2875714285714286 0.281
# Doing batch size: 200, lr: 0.0001, reg: 5e-06
# iteration 0 / 1000: loss 2.302582
# iteration 100 / 1000: loss 2.302125
# iteration 200 / 1000: loss 2.297727
# iteration 300 / 1000: loss 2.264341
# iteration 400 / 1000: loss 2.179532
# iteration 500 / 1000: loss 2.158713
# iteration 600 / 1000: loss 2.059329
# iteration 700 / 1000: loss 2.022076
# iteration 800 / 1000: loss 2.075014
# iteration 900 / 1000: loss 1.946824
# Training, Validation accuracy:  0.28185714285714286 0.284
# Doing batch size: 250, lr: 0.0001, reg: 5e-06
# iteration 0 / 1000: loss 2.302601
# iteration 100 / 1000: loss 2.302153
# iteration 200 / 1000: loss 2.296876
# iteration 300 / 1000: loss 2.272726
# iteration 400 / 1000: loss 2.174672
# iteration 500 / 1000: loss 2.153783
# iteration 600 / 1000: loss 2.118031
# iteration 700 / 1000: loss 2.031456
# iteration 800 / 1000: loss 2.019550
# iteration 900 / 1000: loss 2.026276
# Training, Validation accuracy:  0.282734693877551 0.281
# Doing batch size: 300, lr: 0.0001, reg: 5e-06
# iteration 0 / 1000: loss 2.302582
# iteration 100 / 1000: loss 2.302229
# iteration 200 / 1000: loss 2.298376
# iteration 300 / 1000: loss 2.257613
# iteration 400 / 1000: loss 2.176856
# iteration 500 / 1000: loss 2.129115
# iteration 600 / 1000: loss 2.087299
# iteration 700 / 1000: loss 2.067380
# iteration 800 / 1000: loss 1.934226
# iteration 900 / 1000: loss 1.928046
# Training, Validation accuracy:  0.29889795918367346 0.285
# Doing batch size: 100, lr: 0.0001, reg: 0.25
# iteration 0 / 1000: loss 2.302983
# iteration 100 / 1000: loss 2.302575
# iteration 200 / 1000: loss 2.298271
# iteration 300 / 1000: loss 2.257284
# iteration 400 / 1000: loss 2.206974
# iteration 500 / 1000: loss 2.110155
# iteration 600 / 1000: loss 2.108186
# iteration 700 / 1000: loss 2.120436
# iteration 800 / 1000: loss 1.967458
# iteration 900 / 1000: loss 1.934643
# Training, Validation accuracy:  0.2940408163265306 0.293
# Doing batch size: 200, lr: 0.0001, reg: 0.25
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302356
# iteration 200 / 1000: loss 2.296553
# iteration 300 / 1000: loss 2.252740
# iteration 400 / 1000: loss 2.211261
# iteration 500 / 1000: loss 2.153008
# iteration 600 / 1000: loss 2.152665
# iteration 700 / 1000: loss 2.068068
# iteration 800 / 1000: loss 2.024556
# iteration 900 / 1000: loss 1.958245
# Training, Validation accuracy:  0.28389795918367344 0.283
# Doing batch size: 250, lr: 0.0001, reg: 0.25
# iteration 0 / 1000: loss 2.302974
# iteration 100 / 1000: loss 2.302538
# iteration 200 / 1000: loss 2.295247
# iteration 300 / 1000: loss 2.265885
# iteration 400 / 1000: loss 2.207459
# iteration 500 / 1000: loss 2.095731
# iteration 600 / 1000: loss 2.073037
# iteration 700 / 1000: loss 2.088034
# iteration 800 / 1000: loss 2.028828
# iteration 900 / 1000: loss 1.957547
# Training, Validation accuracy:  0.2808163265306122 0.281
# Doing batch size: 300, lr: 0.0001, reg: 0.25
# iteration 0 / 1000: loss 2.302974
# iteration 100 / 1000: loss 2.302552
# iteration 200 / 1000: loss 2.298649
# iteration 300 / 1000: loss 2.266408
# iteration 400 / 1000: loss 2.187538
# iteration 500 / 1000: loss 2.105551
# iteration 600 / 1000: loss 2.059100
# iteration 700 / 1000: loss 2.043035
# iteration 800 / 1000: loss 2.016600
# iteration 900 / 1000: loss 1.939739
# Training, Validation accuracy:  0.3002448979591837 0.296
# Doing batch size: 100, lr: 0.0003, reg: 5e-05
# iteration 0 / 1000: loss 2.302616
# iteration 100 / 1000: loss 2.251135
# iteration 200 / 1000: loss 2.055060
# iteration 300 / 1000: loss 1.854993
# iteration 400 / 1000: loss 1.955373
# iteration 500 / 1000: loss 1.862663
# iteration 600 / 1000: loss 1.858438
# iteration 700 / 1000: loss 1.866010
# iteration 800 / 1000: loss 1.802728
# iteration 900 / 1000: loss 1.782144
# Training, Validation accuracy:  0.40210204081632656 0.41
# Doing batch size: 200, lr: 0.0003, reg: 5e-05
# iteration 0 / 1000: loss 2.302602
# iteration 100 / 1000: loss 2.251263
# iteration 200 / 1000: loss 2.032020
# iteration 300 / 1000: loss 2.007396
# iteration 400 / 1000: loss 1.856306
# iteration 500 / 1000: loss 1.763236
# iteration 600 / 1000: loss 1.830157
# iteration 700 / 1000: loss 1.653893
# iteration 800 / 1000: loss 1.701486
# iteration 900 / 1000: loss 1.762435
# Training, Validation accuracy:  0.4106326530612245 0.398
# Doing batch size: 250, lr: 0.0003, reg: 5e-05
# iteration 0 / 1000: loss 2.302573
# iteration 100 / 1000: loss 2.276495
# iteration 200 / 1000: loss 2.135792
# iteration 300 / 1000: loss 1.882957
# iteration 400 / 1000: loss 1.952692
# iteration 500 / 1000: loss 1.758634
# iteration 600 / 1000: loss 1.785589
# iteration 700 / 1000: loss 1.767693
# iteration 800 / 1000: loss 1.682924
# iteration 900 / 1000: loss 1.653708
# Training, Validation accuracy:  0.40377551020408164 0.393
# Doing batch size: 300, lr: 0.0003, reg: 5e-05
# iteration 0 / 1000: loss 2.302573
# iteration 100 / 1000: loss 2.267099
# iteration 200 / 1000: loss 2.087498
# iteration 300 / 1000: loss 1.994633
# iteration 400 / 1000: loss 1.827020
# iteration 500 / 1000: loss 1.818988
# iteration 600 / 1000: loss 1.666596
# iteration 700 / 1000: loss 1.721449
# iteration 800 / 1000: loss 1.849457
# iteration 900 / 1000: loss 1.624495
# Training, Validation accuracy:  0.410265306122449 0.427
# Doing batch size: 100, lr: 0.0003, reg: 7e-05
# iteration 0 / 1000: loss 2.302583
# iteration 100 / 1000: loss 2.242740
# iteration 200 / 1000: loss 2.132974
# iteration 300 / 1000: loss 1.801753
# iteration 400 / 1000: loss 1.698531
# iteration 500 / 1000: loss 1.891792
# iteration 600 / 1000: loss 1.771940
# iteration 700 / 1000: loss 1.802602
# iteration 800 / 1000: loss 1.696535
# iteration 900 / 1000: loss 1.597462
# Training, Validation accuracy:  0.4069387755102041 0.403
# Doing batch size: 200, lr: 0.0003, reg: 7e-05
# iteration 0 / 1000: loss 2.302601
# iteration 100 / 1000: loss 2.277246
# iteration 200 / 1000: loss 2.070900
# iteration 300 / 1000: loss 1.967575
# iteration 400 / 1000: loss 1.852889
# iteration 500 / 1000: loss 1.736330
# iteration 600 / 1000: loss 1.785305
# iteration 700 / 1000: loss 1.636728
# iteration 800 / 1000: loss 1.875227
# iteration 900 / 1000: loss 1.758302
# Training, Validation accuracy:  0.40969387755102044 0.407
# Doing batch size: 250, lr: 0.0003, reg: 7e-05
# iteration 0 / 1000: loss 2.302598
# iteration 100 / 1000: loss 2.257365
# iteration 200 / 1000: loss 2.027471
# iteration 300 / 1000: loss 2.012639
# iteration 400 / 1000: loss 1.921133
# iteration 500 / 1000: loss 1.859702
# iteration 600 / 1000: loss 1.700839
# iteration 700 / 1000: loss 1.754548
# iteration 800 / 1000: loss 1.632204
# iteration 900 / 1000: loss 1.743989
# Training, Validation accuracy:  0.4052857142857143 0.401
# Doing batch size: 300, lr: 0.0003, reg: 7e-05
# iteration 0 / 1000: loss 2.302554
# iteration 100 / 1000: loss 2.261253
# iteration 200 / 1000: loss 1.978928
# iteration 300 / 1000: loss 1.966479
# iteration 400 / 1000: loss 1.926637
# iteration 500 / 1000: loss 1.841543
# iteration 600 / 1000: loss 1.759303
# iteration 700 / 1000: loss 1.736822
# iteration 800 / 1000: loss 1.604052
# iteration 900 / 1000: loss 1.648818
# Training, Validation accuracy:  0.4114897959183674 0.417
# Doing batch size: 100, lr: 0.0003, reg: 5e-06
# iteration 0 / 1000: loss 2.302543
# iteration 100 / 1000: loss 2.261532
# iteration 200 / 1000: loss 1.974596
# iteration 300 / 1000: loss 1.960847
# iteration 400 / 1000: loss 1.839754
# iteration 500 / 1000: loss 1.606432
# iteration 600 / 1000: loss 1.629255
# iteration 700 / 1000: loss 1.815222
# iteration 800 / 1000: loss 1.645101
# iteration 900 / 1000: loss 1.679632
# Training, Validation accuracy:  0.40889795918367344 0.402
# Doing batch size: 200, lr: 0.0003, reg: 5e-06
# iteration 0 / 1000: loss 2.302570
# iteration 100 / 1000: loss 2.269726
# iteration 200 / 1000: loss 2.103472
# iteration 300 / 1000: loss 1.952111
# iteration 400 / 1000: loss 1.889569
# iteration 500 / 1000: loss 1.886410
# iteration 600 / 1000: loss 1.711941
# iteration 700 / 1000: loss 1.804661
# iteration 800 / 1000: loss 1.749302
# iteration 900 / 1000: loss 1.708870
# Training, Validation accuracy:  0.4059591836734694 0.41
# Doing batch size: 250, lr: 0.0003, reg: 5e-06
# iteration 0 / 1000: loss 2.302561
# iteration 100 / 1000: loss 2.249012
# iteration 200 / 1000: loss 2.073278
# iteration 300 / 1000: loss 2.005716
# iteration 400 / 1000: loss 1.919897
# iteration 500 / 1000: loss 1.854275
# iteration 600 / 1000: loss 1.742037
# iteration 700 / 1000: loss 1.828986
# iteration 800 / 1000: loss 1.724596
# iteration 900 / 1000: loss 1.695814
# Training, Validation accuracy:  0.4060612244897959 0.403
# Doing batch size: 300, lr: 0.0003, reg: 5e-06
# iteration 0 / 1000: loss 2.302575
# iteration 100 / 1000: loss 2.249678
# iteration 200 / 1000: loss 2.050471
# iteration 300 / 1000: loss 1.981202
# iteration 400 / 1000: loss 1.894371
# iteration 500 / 1000: loss 1.773369
# iteration 600 / 1000: loss 1.743250
# iteration 700 / 1000: loss 1.670298
# iteration 800 / 1000: loss 1.761563
# iteration 900 / 1000: loss 1.624514
# Training, Validation accuracy:  0.41253061224489795 0.413
# Doing batch size: 100, lr: 0.0003, reg: 0.25
# iteration 0 / 1000: loss 2.302963
# iteration 100 / 1000: loss 2.252750
# iteration 200 / 1000: loss 2.051820
# iteration 300 / 1000: loss 2.042855
# iteration 400 / 1000: loss 1.880095
# iteration 500 / 1000: loss 1.829267
# iteration 600 / 1000: loss 1.909165
# iteration 700 / 1000: loss 1.822610
# iteration 800 / 1000: loss 1.597735
# iteration 900 / 1000: loss 1.746924
# Training, Validation accuracy:  0.401734693877551 0.405
# Doing batch size: 200, lr: 0.0003, reg: 0.25
# iteration 0 / 1000: loss 2.302970
# iteration 100 / 1000: loss 2.276818
# iteration 200 / 1000: loss 2.069575
# iteration 300 / 1000: loss 2.024922
# iteration 400 / 1000: loss 1.912339
# iteration 500 / 1000: loss 1.759096
# iteration 600 / 1000: loss 1.760339
# iteration 700 / 1000: loss 1.694135
# iteration 800 / 1000: loss 1.728769
# iteration 900 / 1000: loss 1.734586
# Training, Validation accuracy:  0.4020204081632653 0.405
# Doing batch size: 250, lr: 0.0003, reg: 0.25
# iteration 0 / 1000: loss 2.302983
# iteration 100 / 1000: loss 2.262131
# iteration 200 / 1000: loss 2.120011
# iteration 300 / 1000: loss 1.933776
# iteration 400 / 1000: loss 1.869577
# iteration 500 / 1000: loss 1.784046
# iteration 600 / 1000: loss 1.780466
# iteration 700 / 1000: loss 1.880702
# iteration 800 / 1000: loss 1.691689
# iteration 900 / 1000: loss 1.775623
# Training, Validation accuracy:  0.40246938775510205 0.398
# Doing batch size: 300, lr: 0.0003, reg: 0.25
# iteration 0 / 1000: loss 2.303006
# iteration 100 / 1000: loss 2.271056
# iteration 200 / 1000: loss 2.054509
# iteration 300 / 1000: loss 1.875664
# iteration 400 / 1000: loss 1.832190
# iteration 500 / 1000: loss 1.796186
# iteration 600 / 1000: loss 1.737360
# iteration 700 / 1000: loss 1.758890
# iteration 800 / 1000: loss 1.638955
# iteration 900 / 1000: loss 1.711370
# Training, Validation accuracy:  0.4096530612244898 0.413
# Doing batch size: 100, lr: 0.002, reg: 5e-05
# iteration 0 / 1000: loss 2.302617
# iteration 100 / 1000: loss 1.690885
# iteration 200 / 1000: loss 1.820583
# iteration 300 / 1000: loss 1.710570
# iteration 400 / 1000: loss 1.696253
# iteration 500 / 1000: loss 1.578871
# iteration 600 / 1000: loss 1.761730
# iteration 700 / 1000: loss 1.633580
# iteration 800 / 1000: loss 1.602584
# iteration 900 / 1000: loss 1.589217
# Training, Validation accuracy:  0.45987755102040817 0.441
# Doing batch size: 200, lr: 0.002, reg: 5e-05
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 1.818960
# iteration 200 / 1000: loss 1.807312
# iteration 300 / 1000: loss 1.545018
# iteration 400 / 1000: loss 1.537567
# iteration 500 / 1000: loss 1.577813
# iteration 600 / 1000: loss 1.446318
# iteration 700 / 1000: loss 1.726130
# iteration 800 / 1000: loss 1.460079
# iteration 900 / 1000: loss 1.620581
# Training, Validation accuracy:  0.5038775510204082 0.484
# Doing batch size: 250, lr: 0.002, reg: 5e-05
# iteration 0 / 1000: loss 2.302587
# iteration 100 / 1000: loss 1.817332
# iteration 200 / 1000: loss 1.576751
# iteration 300 / 1000: loss 1.641800
# iteration 400 / 1000: loss 1.380895
# iteration 500 / 1000: loss 1.650213
# iteration 600 / 1000: loss 1.461623
# iteration 700 / 1000: loss 1.329082
# iteration 800 / 1000: loss 1.381845
# iteration 900 / 1000: loss 1.603500
# Training, Validation accuracy:  0.5082244897959184 0.496
# Doing batch size: 300, lr: 0.002, reg: 5e-05
# iteration 0 / 1000: loss 2.302598
# iteration 100 / 1000: loss 1.727282
# iteration 200 / 1000: loss 1.619339
# iteration 300 / 1000: loss 1.618047
# iteration 400 / 1000: loss 1.570834
# iteration 500 / 1000: loss 1.458794
# iteration 600 / 1000: loss 1.626379
# iteration 700 / 1000: loss 1.354269
# iteration 800 / 1000: loss 1.454832
# iteration 900 / 1000: loss 1.476226
# Training, Validation accuracy:  0.5066326530612245 0.464
# Doing batch size: 100, lr: 0.002, reg: 7e-05
# iteration 0 / 1000: loss 2.302616
# iteration 100 / 1000: loss 1.791123
# iteration 200 / 1000: loss 1.667453
# iteration 300 / 1000: loss 1.748405
# iteration 400 / 1000: loss 1.651640
# iteration 500 / 1000: loss 1.625892
# iteration 600 / 1000: loss 1.340807
# iteration 700 / 1000: loss 1.578363
# iteration 800 / 1000: loss 1.719365
# iteration 900 / 1000: loss 1.537656
# Training, Validation accuracy:  0.466265306122449 0.451
# Doing batch size: 200, lr: 0.002, reg: 7e-05
# iteration 0 / 1000: loss 2.302579
# iteration 100 / 1000: loss 1.838253
# iteration 200 / 1000: loss 1.684635
# iteration 300 / 1000: loss 1.448261
# iteration 400 / 1000: loss 1.632939
# iteration 500 / 1000: loss 1.535796
# iteration 600 / 1000: loss 1.577570
# iteration 700 / 1000: loss 1.440926
# iteration 800 / 1000: loss 1.418858
# iteration 900 / 1000: loss 1.600019
# Training, Validation accuracy:  0.504734693877551 0.479
# Doing batch size: 250, lr: 0.002, reg: 7e-05
# iteration 0 / 1000: loss 2.302602
# iteration 100 / 1000: loss 1.808759
# iteration 200 / 1000: loss 1.647700
# iteration 300 / 1000: loss 1.715388
# iteration 400 / 1000: loss 1.639925
# iteration 500 / 1000: loss 1.524082
# iteration 600 / 1000: loss 1.424771
# iteration 700 / 1000: loss 1.343390
# iteration 800 / 1000: loss 1.441509
# iteration 900 / 1000: loss 1.625310
# Training, Validation accuracy:  0.5103265306122449 0.477
# Doing batch size: 300, lr: 0.002, reg: 7e-05
# iteration 0 / 1000: loss 2.302592
# iteration 100 / 1000: loss 1.744752
# iteration 200 / 1000: loss 1.634425
# iteration 300 / 1000: loss 1.641834
# iteration 400 / 1000: loss 1.566165
# iteration 500 / 1000: loss 1.625703
# iteration 600 / 1000: loss 1.392365
# iteration 700 / 1000: loss 1.450640
# iteration 800 / 1000: loss 1.528173
# iteration 900 / 1000: loss 1.385849
# Training, Validation accuracy:  0.4833877551020408 0.459
# Doing batch size: 100, lr: 0.002, reg: 5e-06
# iteration 0 / 1000: loss 2.302566
# iteration 100 / 1000: loss 1.850489
# iteration 200 / 1000: loss 1.614519
# iteration 300 / 1000: loss 1.925824
# iteration 400 / 1000: loss 1.752071
# iteration 500 / 1000: loss 1.625733
# iteration 600 / 1000: loss 1.534296
# iteration 700 / 1000: loss 1.749765
# iteration 800 / 1000: loss 1.500382
# iteration 900 / 1000: loss 1.464642
# Training, Validation accuracy:  0.4637142857142857 0.45
# Doing batch size: 200, lr: 0.002, reg: 5e-06
# iteration 0 / 1000: loss 2.302618
# iteration 100 / 1000: loss 1.791570
# iteration 200 / 1000: loss 1.574410
# iteration 300 / 1000: loss 1.633332
# iteration 400 / 1000: loss 1.644134
# iteration 500 / 1000: loss 1.525887
# iteration 600 / 1000: loss 1.484740
# iteration 700 / 1000: loss 1.478459
# iteration 800 / 1000: loss 1.555988
# iteration 900 / 1000: loss 1.552980
# Training, Validation accuracy:  0.49348979591836734 0.469
# Doing batch size: 250, lr: 0.002, reg: 5e-06
# iteration 0 / 1000: loss 2.302570
# iteration 100 / 1000: loss 1.804225
# iteration 200 / 1000: loss 1.586648
# iteration 300 / 1000: loss 1.429135
# iteration 400 / 1000: loss 1.513713
# iteration 500 / 1000: loss 1.404810
# iteration 600 / 1000: loss 1.544818
# iteration 700 / 1000: loss 1.768169
# iteration 800 / 1000: loss 1.506336
# iteration 900 / 1000: loss 1.359071
# Training, Validation accuracy:  0.4929591836734694 0.479
# Doing batch size: 300, lr: 0.002, reg: 5e-06
# iteration 0 / 1000: loss 2.302562
# iteration 100 / 1000: loss 1.751249
# iteration 200 / 1000: loss 1.654437
# iteration 300 / 1000: loss 1.641082
# iteration 400 / 1000: loss 1.527914
# iteration 500 / 1000: loss 1.522934
# iteration 600 / 1000: loss 1.456163
# iteration 700 / 1000: loss 1.478994
# iteration 800 / 1000: loss 1.475345
# iteration 900 / 1000: loss 1.373670
# Training, Validation accuracy:  0.5025102040816326 0.465
# Doing batch size: 100, lr: 0.002, reg: 0.25
# iteration 0 / 1000: loss 2.302949
# iteration 100 / 1000: loss 1.843232
# iteration 200 / 1000: loss 1.804987
# iteration 300 / 1000: loss 1.655171
# iteration 400 / 1000: loss 1.632501
# iteration 500 / 1000: loss 1.615983
# iteration 600 / 1000: loss 1.506360
# iteration 700 / 1000: loss 1.648191
# iteration 800 / 1000: loss 1.771128
# iteration 900 / 1000: loss 1.884475
# Training, Validation accuracy:  0.45924489795918366 0.448
# Doing batch size: 200, lr: 0.002, reg: 0.25
# iteration 0 / 1000: loss 2.302932
# iteration 100 / 1000: loss 1.760527
# iteration 200 / 1000: loss 1.672498
# iteration 300 / 1000: loss 1.583263
# iteration 400 / 1000: loss 1.681915
# iteration 500 / 1000: loss 1.646654
# iteration 600 / 1000: loss 1.767364
# iteration 700 / 1000: loss 1.656737
# iteration 800 / 1000: loss 1.593558
# iteration 900 / 1000: loss 1.535939
# Training, Validation accuracy:  0.4876326530612245 0.459
# Doing batch size: 250, lr: 0.002, reg: 0.25
# iteration 0 / 1000: loss 2.302952
# iteration 100 / 1000: loss 1.835400
# iteration 200 / 1000: loss 1.645964
# iteration 300 / 1000: loss 1.647035
# iteration 400 / 1000: loss 1.715160
# iteration 500 / 1000: loss 1.500518
# iteration 600 / 1000: loss 1.538015
# iteration 700 / 1000: loss 1.536293
# iteration 800 / 1000: loss 1.597246
# iteration 900 / 1000: loss 1.408856
# Training, Validation accuracy:  0.5028367346938776 0.454
# Doing batch size: 300, lr: 0.002, reg: 0.25
# iteration 0 / 1000: loss 2.302979
# iteration 100 / 1000: loss 1.881910
# iteration 200 / 1000: loss 1.625717
# iteration 300 / 1000: loss 1.685298
# iteration 400 / 1000: loss 1.613262
# iteration 500 / 1000: loss 1.530267
# iteration 600 / 1000: loss 1.529182
# iteration 700 / 1000: loss 1.510161
# iteration 800 / 1000: loss 1.606162
# iteration 900 / 1000: loss 1.526638
# Training, Validation accuracy:  0.4840204081632653 0.451
# Doing batch size: 100, lr: 0.003, reg: 5e-05
# iteration 0 / 1000: loss 2.302575
# iteration 100 / 1000: loss 1.979858
# iteration 200 / 1000: loss 1.721335
# iteration 300 / 1000: loss 1.943641
# iteration 400 / 1000: loss 1.928065
# iteration 500 / 1000: loss 1.946077
# iteration 600 / 1000: loss 1.931240
# iteration 700 / 1000: loss 2.429517
# iteration 800 / 1000: loss 1.684361
# iteration 900 / 1000: loss 1.850270
# Training, Validation accuracy:  0.42720408163265305 0.41
# Doing batch size: 200, lr: 0.003, reg: 5e-05
# iteration 0 / 1000: loss 2.302569
# iteration 100 / 1000: loss 1.797513
# iteration 200 / 1000: loss 1.636249
# iteration 300 / 1000: loss 1.908885
# iteration 400 / 1000: loss 1.699216
# iteration 500 / 1000: loss 1.662748
# iteration 600 / 1000: loss 1.525892
# iteration 700 / 1000: loss 1.565945
# iteration 800 / 1000: loss 1.554039
# iteration 900 / 1000: loss 1.491130
# Training, Validation accuracy:  0.4536938775510204 0.412
# Doing batch size: 250, lr: 0.003, reg: 5e-05
# iteration 0 / 1000: loss 2.302603
# iteration 100 / 1000: loss 1.731173
# iteration 200 / 1000: loss 1.678121
# iteration 300 / 1000: loss 1.681519
# iteration 400 / 1000: loss 1.481825
# iteration 500 / 1000: loss 1.586560
# iteration 600 / 1000: loss 1.381163
# iteration 700 / 1000: loss 1.672222
# iteration 800 / 1000: loss 1.444508
# iteration 900 / 1000: loss 1.540653
# Training, Validation accuracy:  0.48516326530612247 0.453
# Doing batch size: 300, lr: 0.003, reg: 5e-05
# iteration 0 / 1000: loss 2.302563
# iteration 100 / 1000: loss 1.698919
# iteration 200 / 1000: loss 1.883229
# iteration 300 / 1000: loss 1.886744
# iteration 400 / 1000: loss 1.506571
# iteration 500 / 1000: loss 1.478467
# iteration 600 / 1000: loss 1.542294
# iteration 700 / 1000: loss 1.601009
# iteration 800 / 1000: loss 1.588324
# iteration 900 / 1000: loss 1.553388
# Training, Validation accuracy:  0.46146938775510205 0.451
# Doing batch size: 100, lr: 0.003, reg: 7e-05
# iteration 0 / 1000: loss 2.302593
# iteration 100 / 1000: loss 1.779479
# iteration 200 / 1000: loss 1.902712
# iteration 300 / 1000: loss 1.925211
# iteration 400 / 1000: loss 1.654904
# iteration 500 / 1000: loss 2.299524
# iteration 600 / 1000: loss 2.210339
# iteration 700 / 1000: loss 1.525233
# iteration 800 / 1000: loss 1.677399
# iteration 900 / 1000: loss 2.073451
# Training, Validation accuracy:  0.3709183673469388 0.345
# Doing batch size: 200, lr: 0.003, reg: 7e-05
# iteration 0 / 1000: loss 2.302553
# iteration 100 / 1000: loss 1.867325
# iteration 200 / 1000: loss 1.789848
# iteration 300 / 1000: loss 1.840167
# iteration 400 / 1000: loss 1.810690
# iteration 500 / 1000: loss 1.636898
# iteration 600 / 1000: loss 1.690600
# iteration 700 / 1000: loss 1.406906
# iteration 800 / 1000: loss 1.674923
# iteration 900 / 1000: loss 1.599284
# Training, Validation accuracy:  0.44204081632653064 0.421
# Doing batch size: 250, lr: 0.003, reg: 7e-05
# iteration 0 / 1000: loss 2.302576
# iteration 100 / 1000: loss 1.734114
# iteration 200 / 1000: loss 1.701547
# iteration 300 / 1000: loss 1.642378
# iteration 400 / 1000: loss 1.744233
# iteration 500 / 1000: loss 1.419223
# iteration 600 / 1000: loss 1.671472
# iteration 700 / 1000: loss 1.602073
# iteration 800 / 1000: loss 1.549150
# iteration 900 / 1000: loss 1.394499
# Training, Validation accuracy:  0.5009795918367347 0.454
# Doing batch size: 300, lr: 0.003, reg: 7e-05
# iteration 0 / 1000: loss 2.302567
# iteration 100 / 1000: loss 1.775895
# iteration 200 / 1000: loss 1.727379
# iteration 300 / 1000: loss 1.653953
# iteration 400 / 1000: loss 1.647630
# iteration 500 / 1000: loss 1.689623
# iteration 600 / 1000: loss 1.620230
# iteration 700 / 1000: loss 1.650321
# iteration 800 / 1000: loss 1.544327
# iteration 900 / 1000: loss 1.741441
# Training, Validation accuracy:  0.4429387755102041 0.432
# Doing batch size: 100, lr: 0.003, reg: 5e-06
# iteration 0 / 1000: loss 2.302556
# iteration 100 / 1000: loss 1.999332
# iteration 200 / 1000: loss 1.790191
# iteration 300 / 1000: loss 2.044856
# iteration 400 / 1000: loss 1.756519
# iteration 500 / 1000: loss 1.839681
# iteration 600 / 1000: loss 1.653496
# iteration 700 / 1000: loss 1.706075
# iteration 800 / 1000: loss 2.335053
# iteration 900 / 1000: loss 1.814500
# Training, Validation accuracy:  0.3846734693877551 0.351
# Doing batch size: 200, lr: 0.003, reg: 5e-06
# iteration 0 / 1000: loss 2.302598
# iteration 100 / 1000: loss 1.772045
# iteration 200 / 1000: loss 1.658316
# iteration 300 / 1000: loss 1.743981
# iteration 400 / 1000: loss 1.682517
# iteration 500 / 1000: loss 1.646377
# iteration 600 / 1000: loss 1.610885
# iteration 700 / 1000: loss 1.597123
# iteration 800 / 1000: loss 1.709581
# iteration 900 / 1000: loss 1.595557
# Training, Validation accuracy:  0.4561428571428571 0.444
# Doing batch size: 250, lr: 0.003, reg: 5e-06
# iteration 0 / 1000: loss 2.302577
# iteration 100 / 1000: loss 1.783601
# iteration 200 / 1000: loss 1.758611
# iteration 300 / 1000: loss 1.684860
# iteration 400 / 1000: loss 1.474176
# iteration 500 / 1000: loss 1.683853
# iteration 600 / 1000: loss 1.499832
# iteration 700 / 1000: loss 1.581090
# iteration 800 / 1000: loss 1.347515
# iteration 900 / 1000: loss 1.581129
# Training, Validation accuracy:  0.5006326530612245 0.484
# Doing batch size: 300, lr: 0.003, reg: 5e-06
# iteration 0 / 1000: loss 2.302585
# iteration 100 / 1000: loss 1.774709
# iteration 200 / 1000: loss 1.773019
# iteration 300 / 1000: loss 1.760412
# iteration 400 / 1000: loss 1.589001
# iteration 500 / 1000: loss 1.568185
# iteration 600 / 1000: loss 1.688605
# iteration 700 / 1000: loss 1.428504
# iteration 800 / 1000: loss 1.617892
# iteration 900 / 1000: loss 1.804960
# Training, Validation accuracy:  0.5197142857142857 0.489
# Doing batch size: 100, lr: 0.003, reg: 0.25
# iteration 0 / 1000: loss 2.302976
# iteration 100 / 1000: loss 1.916009
# iteration 200 / 1000: loss 1.888854
# iteration 300 / 1000: loss 2.123310
# iteration 400 / 1000: loss 1.757007
# iteration 500 / 1000: loss 1.903384
# iteration 600 / 1000: loss 1.875830
# iteration 700 / 1000: loss 2.076992
# iteration 800 / 1000: loss 1.789116
# iteration 900 / 1000: loss 1.841982
# Training, Validation accuracy:  0.38285714285714284 0.391
# Doing batch size: 200, lr: 0.003, reg: 0.25
# iteration 0 / 1000: loss 2.302967
# iteration 100 / 1000: loss 1.755213
# iteration 200 / 1000: loss 1.653726
# iteration 300 / 1000: loss 1.666888
# iteration 400 / 1000: loss 1.602543
# iteration 500 / 1000: loss 1.705659
# iteration 600 / 1000: loss 1.660949
# iteration 700 / 1000: loss 1.633984
# iteration 800 / 1000: loss 1.654859
# iteration 900 / 1000: loss 1.746689
# Training, Validation accuracy:  0.4866938775510204 0.457
# Doing batch size: 250, lr: 0.003, reg: 0.25
# iteration 0 / 1000: loss 2.302976
# iteration 100 / 1000: loss 1.732867
# iteration 200 / 1000: loss 1.700494
# iteration 300 / 1000: loss 1.606769
# iteration 400 / 1000: loss 1.702285
# iteration 500 / 1000: loss 1.760278
# iteration 600 / 1000: loss 1.766973
# iteration 700 / 1000: loss 1.545122
# iteration 800 / 1000: loss 1.583816
# iteration 900 / 1000: loss 1.601640
# Training, Validation accuracy:  0.45546938775510204 0.448
# Doing batch size: 300, lr: 0.003, reg: 0.25
# iteration 0 / 1000: loss 2.302964
# iteration 100 / 1000: loss 1.838635
# iteration 200 / 1000: loss 1.641778
# iteration 300 / 1000: loss 1.691407
# iteration 400 / 1000: loss 1.812010
# iteration 500 / 1000: loss 1.626482
# iteration 600 / 1000: loss 1.799474
# iteration 700 / 1000: loss 1.719787
# iteration 800 / 1000: loss 1.585668
# iteration 900 / 1000: loss 1.783849
# Training, Validation accuracy:  0.44593877551020406 0.422
# lr, reg, batch_size:  [0.002, 5e-05, 250]

# %%
print(best_val)
# Out:
# 0.496

# %%
plot_stats(best_stats)

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.481

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# *Your answer*: 1, 3 true.
#
# *Your explanation:* training on larger dataset will generalize well for testing data given you are adding different examples helping the model learn better. Adding more hidden units could help capture more features in images which will be helpful in testing data prediction but I think even that could be overfitting as we are only increasing the sensitivity of the model, increasing variance. Increasing regularization enforces smoothening of the predictor as discussed in class and hence prevents any peaks in it, leading to a predictor that doesnt overfit.
